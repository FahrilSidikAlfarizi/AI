# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
from statsmodels.api import add_constant
import sklearn

# %%
data=pd.read_csv('/content/placement.csv')
data
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
x1=data['cgpa']
x1
# Out:
# 0      7.19
# 1      7.46
# 2      7.54
# 3      6.42
# 4      7.23
#        ...
# 995    8.87
# 996    9.12
# 997    4.89
# 998    8.62
# 999    4.90
# Name: cgpa, Length: 1000, dtype: float64

# %%
y=data['placement_exam_marks']
y
# Out:
# 0      26.0
# 1      38.0
# 2      40.0
# 3       8.0
# 4      17.0
#        ...
# 995    44.0
# 996    65.0
# 997    34.0
# 998    46.0
# 999    10.0
# Name: placement_exam_marks, Length: 1000, dtype: float64

# %%
plt.scatter(x1,y)
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks',fontsize=20)
plt.title('exam marks prediction',fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
model = sm.OLS(y, x)
result = model.fit()
print(result.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     placement_exam_marks   R-squared:                       0.001
# Model:                              OLS   Adj. R-squared:                 -0.000
# Method:                   Least Squares   F-statistic:                    0.7482
# Date:                  Wed, 14 Jun 2023   Prob (F-statistic):              0.387
# Time:                          15:27:13   Log-Likelihood:                -4369.4
# No. Observations:                  1000   AIC:                             8743.
# Df Residuals:                       998   BIC:                             8753.
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.1434      6.869      5.553      0.000      24.665      51.622
# ...

# %%
plt.scatter(x1,y)
yhat=-0.8502*x1+38.1434
fig=plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('cgpa')
plt.ylabel('placement_exam_marks',fontsize=20)
plt.title('exam marks prediction',fontsize=20)
plt.show()
